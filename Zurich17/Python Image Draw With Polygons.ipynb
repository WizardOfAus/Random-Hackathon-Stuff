# %%
import Image
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-6-e2cc1e534171> in <module>()
# ----> 1 import Image
#
# ImportError: No module named Image

# %%
flowers = Image.open("Brown-Hamster.jpg")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-5569c86875f6> in <module>()
# ----> 1 flowers = Image.open("Brown-Hamster.jpg")
#
# NameError: name 'Image' is not defined

# %%
# !pip install pillow
# Out:
# ...
# You are using pip version 8.1.2, however version 9.0.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
import  PIL

# %%
from PIL import Image

# %%
hamster = Image.open("Brown-Hamster.jpg")

# %%
hamster
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=800x530 at 0x106D0AA10>

# %%
from __future__ import print_function

# %%
print(hamster.format, hamster.size, hamster.mode)
# Out:
# JPEG (800, 530) RGB
